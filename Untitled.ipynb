# %%
def plastic_balance(lst):
    
    while len(lst) > 2:
        inner_lst = lst[1:-1]
        sum_inner_lst = 0
        for i in inner_lst:
            sum_inner_lst =+ i
        if lst[0] + lst[len(lst)-1] != sum_inner_lst:
            lst = inner_lst
        elif lst[0] + lst[len(lst)-1] == sum_inner_lst:
            balance_found = lst
            return balance_found
            
    
    if len(lst) == 2:
        if lst[0] + lst[1] == 0:
            balance_found = lst
        else:
            balance_found = []
        
    return balance_found

# %%
def plastic_balance(lst):
    while len(lst) > 2:
        inner_lst = lst[1:-1]
        sum_inner_lst = 0
        for i in inner_lst:
            sum_inner_lst += i
        if lst[0] + lst[-1] != sum_inner_lst:
            lst = inner_lst
        else:
            return lst  # Return the balanced list when found

    if len(lst) == 2:
        if lst[0] + lst[1] == 0:
            return lst # Return the list if the sum of elements in the list of length 2 equals 0
        
    elif len(lst) == 1 and lst[0] ==0:
        return lst
    

    return []  # Return an empty list if no balance is found

# %%
plastic_balance([2,2,5,5])
# Out:
# [2, 5]

# %%
def plastic_balance(lst):
    
    while len(lst) > 2:
        inner_lst = lst[1:-1]
        sum_inner_lst = 0
        for i in inner_lst:
            sum_inner_lst += i
        if lst[0] + lst[-1] != sum_inner_lst:
            lst = inner_lst
        else:
            return lst  # Return the balanced list when found

    if len(lst) == 2:
        if lst[0] + lst[1] == 0:
            return lst  # Return the list if the sum of elements in the list of length 2 equals 0

    return []  # Return an empty list if no balance is found

# %%
plastic_balance([2,2,5,5])
# Out:
# []

# %%
lst[1:-1]
# Out:
# []

# %%
def plastic_balance(lst):
    condition = False
    while condition == False:
        if len(lst) == 2:
            if lst[0] + lst[1] == 0:
                condition = True

            elif lst[0] + lst[1] != 0:
                lst = []
                condition = True
            
        elif len(lst) > 2:
            inner_lst = lst[1:-1]
            sum_inner_lst = 0
            for i in inner_lst:
                sum_inner_lst += i
                
            if lst[0]+lst[len(lst)-1] != sum_inner_lst:
                lst = inner_lst
            
    return lst

# %%
def plastic_balance(lst):
    condition = False
    while condition == False:
        if len(lst) > 2:
            inner_lst = lst[1:-1]
            sum_inner_lst = 0
            for i in inner_lst:
                sum_inner_lst += i
            if lst[0]+lst[len(lst)-1] != sum_inner_lst:
                lst = inner_lst
            else:
                condition == True
                
        elif len(lst) == 2:
            if lst[0] + lst[1] == 0:
                condition = True

            elif lst[0] + lst[1] != 0:
                lst = []
                condition = True
        elif len(lst) < 2:
            if lst[0] + lst[0] != 0:
                lst = []
                condition = True
            else: condition = True
            
    return lst

# %%
plastic_balance([1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plastic_balance([1,2,3,4,5])
#
# Cell In[17], line 8, in plastic_balance(lst)
#       6 for i in inner_lst:
#       7     sum_inner_lst += i
# ----> 8 if lst[0]+lst[len(lst)-1] != sum_inner_lst:
#       9     lst = inner_lst
#      10 else:
#
# IndexError: list index out of range

# %%
lst = [1,2,3,4,5]
sum_lst = 0
for i in lst:
    sum_lst +=i

# %%
lst = [1,2,3,4,5]

# %%
inner_lst = lst[1:-1]

# %%
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
inner_lst
# Out:
# [2, 3, 4]

# %%
lst[1:-1]
# Out:
# [2, 3, 4]

# %%
lst[len(lst)-1]
# Out:
# 5
